# %% [markdown]
# Importing the package

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist, fashion_mnist
import numpy as np
import keras
from matplotlib import pyplot as plt

# %% [markdown]
# Loading and Preprocessing

# %%
# Loading the Fashion MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Normalizing the inputs from 0-255 to 0.0-1.0
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
# Converting the 2D data to 1D vector format
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Creating the Model

# %%
# Size of encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))
encodedHiddenLayer = Dense(256, activation='relu')(input_img) # Enocoder Hidden Layer with 256 nodes
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(encodedHiddenLayer)

decodedHiddenLayer = Dense(256, activation='relu')(encoded) # Decoder Hideen Layer with 256 nodes
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(decodedHiddenLayer)

# The model maps an input to its reconstruction
autoEncoder = Model(input_img, decoded)
# Changed the learning rate to 1. Since the default learning rate of 0.001 is slowing down the training process.
# We can replace Adadelta with Adam optimizer which is giving better results. 
optimizer = keras.optimizers.Adadelta(learning_rate=1)
autoEncoder.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=["accuracy"])

# %%
autoEncoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               8448
# _________________________________________________________________
# dense_11 (Dense)             (None, 784)               201488
# =================================================================
# Total params: 419,120
# Trainable params: 419,120
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training the Model

# %%
# Fit the model
history = autoEncoder.fit(x_train, x_train, epochs=20, batch_size=256, shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5636 - accuracy: 0.0014 - val_loss: 0.3936 - val_accuracy: 0.0112
# Epoch 2/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3837 - accuracy: 0.0075 - val_loss: 0.3686 - val_accuracy: 0.0068
# Epoch 3/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3581 - accuracy: 0.0050 - val_loss: 0.3443 - val_accuracy: 0.0071
# Epoch 4/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3424 - accuracy: 0.0069 - val_loss: 0.3321 - val_accuracy: 0.0068
# Epoch 5/20
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3322 - accuracy: 0.0102 - val_loss: 0.3303 - val_accuracy: 0.0158
# Epoch 6/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3269 - accuracy: 0.0121 - val_loss: 0.3255 - val_accuracy: 0.0109
# Epoch 7/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3219 - accuracy: 0.0132 - val_loss: 0.3214 - val_accuracy: 0.0155
# Epoch 8/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3195 - accuracy: 0.0129 - val_loss: 0.3182 - val_accuracy: 0.0143
# Epoch 9/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3173 - accuracy: 0.0136 - val_loss: 0.3164 - val_accuracy: 0.0165
# Epoch 10/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3146 - accuracy: 0.0131 - val_loss: 0.3156 - val_accuracy: 0.0144
# Epoch 11/20
# 235/235 [==============================] - 2s 6ms/step - loss: 0.3129 - accuracy: 0.0143 - val_loss: 0.3124 - val_accuracy: 0.0166
# Epoch 12/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3105 - accuracy: 0.0137 - val_loss: 0.3126 - val_accuracy: 0.0153
# Epoch 13/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3092 - accuracy: 0.0156 - val_loss: 0.3116 - val_accuracy: 0.0168
# Epoch 14/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3078 - accuracy: 0.0134 - val_loss: 0.3094 - val_accuracy: 0.0122
# Epoch 15/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3062 - accuracy: 0.0144 - val_loss: 0.3087 - val_accuracy: 0.0130
# Epoch 16/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3059 - accuracy: 0.0141 - val_loss: 0.3067 - val_accuracy: 0.0124
# Epoch 17/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3039 - accuracy: 0.0131 - val_loss: 0.3048 - val_accuracy: 0.0132
# Epoch 18/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3033 - accuracy: 0.0131 - val_loss: 0.3039 - val_accuracy: 0.0130
# Epoch 19/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3028 - accuracy: 0.0121 - val_loss: 0.3047 - val_accuracy: 0.0126
# Epoch 20/20
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3014 - accuracy: 0.0135 - val_loss: 0.3029 - val_accuracy: 0.0138

# %% [markdown]
# Predicition & Visualization on Test data

# %%
prediction = autoEncoder.predict(x_test[[0],:])

# %%
# Plotting the first test image and its generated image using autoEncoder
fig = plt.figure(figsize=(14, 10))

# Original Image
ax = fig.add_subplot(1, 2, 1)
ax.imshow(x_test[0].reshape(28,28))
ax.set_title("Original Image")

# Reconstructed Image
ax = fig.add_subplot(1, 2, 2)
ax.imshow(prediction[0].reshape(28,28))
ax.set_title("Reconstructed Image")

# %% [markdown]
# Loss & Accuracy Visualization during training phase

# %%
# Models Loss/Error value during training phase
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Models's Loss/Error")
plt.legend(["Training", "Validation"])
plt.xlabel("No.of epochs")
plt.ylabel("Loss value")
plt.show()

# Models Accuracy during training phase
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Model's Accuracy")
plt.legend(['Training', 'Validation'])
plt.xlabel('No.of epochs')
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# Bonus Question

# %%
# Getting the middle layer output i.e compressed version
encoder = Model(autoEncoder.layers[0].input,autoEncoder.layers[2].output)
encodedFormat = encoder.predict(x_test[[0],:])

# Plotting the first test image and its generated image using autoEncoder
fig = plt.figure(figsize=(14, 10))

# Original Image
ax = fig.add_subplot(1, 3, 1)
ax.imshow(x_test[0].reshape(28,28))
ax.set_title("Original Image")

# Encoded Representation
ax = fig.add_subplot(1, 3, 3)
ax.imshow(encodedFormat)
ax.set_title("Encoded Representation")
# Out:
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f331eb2d680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Text(0.5, 1.0, 'Encoded Representation')
